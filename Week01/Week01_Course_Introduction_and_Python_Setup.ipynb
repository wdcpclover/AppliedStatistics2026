# %% [markdown]
# # Week 1: Course Introduction & Python Setup
#
# # Applied Statistics with Python (2026)
#
# ---
#
# **Instructor:** Chang Pengcheng
# **Language:** English
# **Tools:** Python, Jupyter Notebook
# **Format:** 18 weeks × 2 hours/week

# %% [markdown]
# ---
# ## 1. Welcome & Course Overview
#
# Welcome to **Applied Statistics with Python**!
#
# This course bridges three powerful fields:
#
# | | What | Why |
# |---|---|---|
# | **Python** | The programming language | The tool to do everything |
# | **Statistics** | The science of data | The theory to understand data |
# | **Machine Learning** | Algorithms that learn from data | The frontier of data science |
#
# ### Course Philosophy
#
# > **"Learning by doing"** — Every concept is accompanied by runnable Python code.
# > You won't just learn statistics — you'll *compute* it, *visualize* it, and *apply* it.

# %% [markdown]
# ---
# ## 2. Course Roadmap
#
# The course is organized into **5 parts** over **18 weeks**:
#
# ```
# Part I:   Python Foundation          (Week 1–4)    ████░░░░░░░░░░░░░░
# Part II:  Applied Statistics         (Week 5–12)   ░░░░████████░░░░░░
# Part III: Web Scraping               (Week 13)     ░░░░░░░░░░░░█░░░░░
# Part IV:  Machine Learning & AI      (Week 14–16)  ░░░░░░░░░░░░░███░░
# Part V:   Paper Replication          (Week 17–18)  ░░░░░░░░░░░░░░░░██
# ```
#
# ### Detailed Breakdown
#
# | Week | Topic |
# |------|-------|
# | 1 | Course Introduction & Python Setup ← **You are here** |
# | 2 | Python Essentials (variables, control flow, functions) |
# | 3 | NumPy & Pandas |
# | 4 | Data Visualization (Matplotlib, Seaborn) |
# | 5 | Descriptive Statistics & EDA |
# | 6 | Probability & Distributions |
# | 7 | Sampling & Estimation |
# | 8 | Hypothesis Testing |
# | 9 | Correlation & Regression |
# | 10 | ANOVA & Non-parametric Methods |
# | 11 | Time Series Analysis |
# | 12 | Bayesian Statistics |
# | 13 | Web Scraping with Python |
# | 14 | ML Fundamentals & Supervised Learning |
# | 15 | Unsupervised Learning & Model Evaluation |
# | 16 | Deep Learning & LLMs |
# | 17–18 | Student Paper Replication Presentations |

# %% [markdown]
# ---
# ## 3. Grading Policy
#
# | Component | Weight | Description |
# |-----------|--------|-------------|
# | Attendance & Participation | 10% | Be present, ask questions, engage |
# | Jupyter Exercises | 30% | 5–6 homework assignments throughout the semester |
# | Paper Replication Report + Code | 30% | Replicate a published paper using Python |
# | Presentation + Q&A | 20% | Present your replication in Week 17–18 |
# | Peer Review | 10% | Review and give feedback to your classmates |
#
# ### Paper Replication Project (Key Dates)
#
# - **Week 6**: Candidate paper list published
# - **Week 8**: Form teams (2–3 students), select paper
# - **Week 13**: Mid-term check — data acquired, methodology understood
# - **Week 16**: Submit replication code + report draft
# - **Week 17–18**: In-class presentation (15 min + 5 min Q&A)

# %% [markdown]
# ---
# ## 4. Recommended Books & Resources
#
# | # | Book | Focus |
# |---|------|-------|
# | 1 | *An Introduction to Statistics with Python* — T. Haslwanter | Statistics + Python |
# | 2 | *An Introduction to Statistical Learning* — James et al. | Statistical learning theory |
# | 3 | *Python for Data Analysis* — Wes McKinney | Pandas & data wrangling |
# | 4 | *Business Statistics: A First Course* — Levine et al. | Statistics fundamentals |
#
# **Online Resources:**
# - [Python Official Documentation](https://docs.python.org/3/)
# - [NumPy User Guide](https://numpy.org/doc/stable/user/)
# - [Pandas Documentation](https://pandas.pydata.org/docs/)
# - [Kaggle Datasets](https://www.kaggle.com/datasets) — free datasets for practice

# %% [markdown]
# ---
# ## 5. Why Python? (And Not R, MATLAB, or Others?)
#
# This is a statistics course. You might wonder: why Python and not R, MATLAB, SAS, or SPSS?
#
# Let's compare honestly.
#
# ### 5.1 Python vs R — The Big Debate
#
# | Dimension | Python | R |
# |-----------|--------|---|
# | **Born for** | General-purpose programming | Statistical computing |
# | **Syntax** | Clean, beginner-friendly | Quirky (e.g., `<-` for assignment) |
# | **Statistics** | Great (scipy, statsmodels, pingouin) | Excellent (built-in, CRAN packages) |
# | **Machine Learning** | Dominant (scikit-learn, PyTorch, TensorFlow) | Good (caret, tidymodels) but smaller ecosystem |
# | **Deep Learning / AI** | Industry standard (PyTorch, HuggingFace) | Very limited |
# | **Visualization** | Matplotlib, Seaborn, Plotly | ggplot2 (beautiful, but R-only) |
# | **Web Scraping** | Excellent (requests, BeautifulSoup, Selenium) | Limited |
# | **Job Market** | #1 in tech, data science, AI | Strong in academia, biostatistics |
# | **Community** | Massive (Stack Overflow, GitHub) | Large but more academic |
# | **Learning Curve** | Easy first language | Steeper for non-statisticians |
#
# ### 5.2 Python vs MATLAB / SAS / SPSS
#
# | Tool | Strengths | Why We Don't Use It |
# |------|-----------|---------------------|
# | **MATLAB** | Engineering, signal processing, simulation | Expensive license ($$$), weak in ML/AI |
# | **SAS** | Enterprise analytics, clinical trials | Expensive, declining market share, closed ecosystem |
# | **SPSS** | Point-and-click statistics, social science | Not programmable, limited to traditional stats |
# | **Stata** | Econometrics, panel data | Niche, expensive, no ML/AI support |
# | **Excel** | Everyone knows it | Not scalable, error-prone, no reproducibility |
#
# ### 5.3 The Real Reason: Python Is the Language of AI
#
# ```
#                     2015            2020            2025
#                     ┌───┐           ┌───┐           ┌───┐
# Statistics:         │ R │           │R/Py│           │ Py│  ← Python catching up
#                     └───┘           └───┘           └───┘
# Machine Learning:   ┌───┐           ┌───┐           ┌───┐
#                     │R/Py│          │ Py│            │ Py│  ← Python dominates
#                     └───┘           └───┘           └───┘
# Deep Learning:      ┌───┐           ┌───┐           ┌───┐
#                     │ Py│           │ Py│            │ Py│  ← Always Python
#                     └───┘           └───┘           └───┘
# LLMs / GenAI:         —              —             ┌───┐
#                                                    │ Py│  ← Python only
#                                                    └───┘
# ```
#
# > **Bottom line:** If you learn Python, you can do statistics AND machine learning AND AI.
# > If you learn R, you can do statistics well, but you'll need to learn Python later anyway.
# > **We choose Python because it gives you the most return on your learning investment.**
#
# ### 5.4 The Python Data Science Stack
#
# ```
# ┌──────────────────────────────────────────────────┐
# │               Your Analysis / Model              │
# ├───────────┬───────────┬───────────┬──────────────┤
# │ scikit-   │ stats-    │ PyMC      │ PyTorch      │
# │ learn     │ models    │ (Bayes)   │ (Deep        │
# │ (ML)      │ (Stats)   │           │  Learning)   │
# ├───────────┴───────────┴───────────┴──────────────┤
# │  Matplotlib / Seaborn / Plotly  (Visualization)  │
# ├──────────────────────────────────────────────────┤
# │  Pandas  (Data Manipulation)                     │
# ├──────────────────────────────────────────────────┤
# │  NumPy  (Numerical Computing)                    │
# ├──────────────────────────────────────────────────┤
# │  Python                                          │
# └──────────────────────────────────────────────────┘
# ```
#
# We will learn this stack **from bottom to top** throughout this course.
#
# ### 5.5 "But My Professor Uses R..."
#
# That's fine! The statistical **concepts** are the same regardless of language.
#
# | Concept | Python | R |
# |---------|--------|---|
# | t-test | `scipy.stats.ttest_ind(a, b)` | `t.test(a, b)` |
# | Linear regression | `statsmodels.OLS(y, X).fit()` | `lm(y ~ x, data)` |
# | Histogram | `plt.hist(data)` | `hist(data)` |
#
# Once you understand the statistics, switching between languages is easy.
# But the **programming skills, ML skills, and AI skills** you learn in Python are not easily replicated in R.

# %% [markdown]
# ---
# ## 6. Anaconda: Your Data Science Toolkit
#
# ### 6.1 What is Anaconda?
#
# Anaconda is a **free, open-source distribution of Python** designed specifically for data science.
#
# | Without Anaconda | With Anaconda |
# |-----------------|---------------|
# | Install Python manually | Python pre-installed |
# | Install each library one by one | 250+ libraries pre-installed |
# | Manage versions manually, fix conflicts yourself | Conda package manager handles everything |
# | Environment setup takes hours | Ready to go in 10 minutes |
#
# > **Analogy:** Installing Python alone is like buying a kitchen with no appliances.
# > Installing Anaconda is like moving into a fully-equipped kitchen — oven, fridge, blender, everything ready.
#
# ### 6.2 What's Inside Anaconda?
#
# ```
# ┌─── Anaconda Distribution ──────────────────────────────────┐
# │                                                            │
# │  Python 3.12+                                              │
# │                                                            │
# │  250+ Pre-installed Packages:                              │
# │     NumPy, Pandas, Matplotlib, Seaborn, SciPy,            │
# │     scikit-learn, statsmodels, Jupyter, and more...        │
# │                                                            │
# │  Conda — Package & Environment Manager                    │
# │                                                            │
# │  Anaconda Navigator — Graphical Interface                  │
# │                                                            │
# │  Jupyter Notebook — Interactive Coding Environment         │
# │                                                            │
# └────────────────────────────────────────────────────────────┘
# ```
#
# ### 6.3 Installing Anaconda
#
# **Step 1: Download** from [https://www.anaconda.com/download](https://www.anaconda.com/download)
#
# **Step 2: Install**
#
# - **Windows:** Run `.exe` → Select "Just Me" → Check "Add to PATH" → Install
# - **macOS:** Run `.pkg` → Follow prompts → Done
# - **Linux:** `bash Anaconda3-2024.xx-Linux-x86_64.sh`
#
# **Step 3: Verify** — Run the cell below:

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python location: {sys.executable}")

import numpy as np
print(f"\nNumPy version:      {np.__version__}")

import pandas as pd
print(f"Pandas version:     {pd.__version__}")

import matplotlib
print(f"Matplotlib version: {matplotlib.__version__}")

import scipy
print(f"SciPy version:      {scipy.__version__}")

import sklearn
print(f"Scikit-learn:       {sklearn.__version__}")

print("\nAll good! Your environment is ready.")
# Out:
# Python version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]
# Python location: /opt/anaconda3/bin/python
#
# NumPy version:      2.2.5
# Pandas version:     2.2.2
# Matplotlib version: 3.10.0
# SciPy version:      1.15.3
# Scikit-learn:       1.6.1
#
# All good! Your environment is ready.

# %% [markdown]
# ### 6.4 Conda Essentials
#
# Conda is the command-line tool that comes with Anaconda:
#
# ```bash
# conda --version              # Check version
# conda list                   # List installed packages
# conda install pymc           # Install a package
# conda update numpy           # Update a package
# conda create -n stats2026 python=3.12   # Create environment
# conda activate stats2026     # Activate environment
# conda deactivate             # Deactivate
# ```
#
# ### 6.5 Conda vs Pip
#
# | | Conda | Pip |
# |---|-------|-----|
# | **Source** | Anaconda repository | PyPI |
# | **Manages** | Python + C/system dependencies | Python packages only |
# | **Best for** | Data science (NumPy, SciPy, PyTorch) | General Python packages |
#
# > **Rule of thumb:** Try `conda install` first. If not available, use `pip install`.
#
# ### 6.6 Launching Jupyter Notebook
#
# **Option A:** Anaconda Navigator → Click "Launch" under Jupyter Notebook
# **Option B:** Terminal → `jupyter notebook` → browser opens at `localhost:8888`
#
# Then: **New → Python 3** → Start coding!

# %% [markdown]
# ---
# ## 7. Learning in the AI Era
#
# ### 7.1 The Elephant in the Room
#
# **ChatGPT, Claude, GitHub Copilot** — AI can write code. So why learn programming at all?
#
# ### 7.2 What AI Can and Cannot Do
#
# | AI Can | AI Cannot |
# |--------|----------|
# | Write syntactically correct code | Understand your specific research question |
# | Explain concepts clearly | Know if the statistical method is appropriate |
# | Debug simple errors | Judge whether results make scientific sense |
# | Generate boilerplate code | Design a novel experiment or analysis |
# | Translate between languages | Take responsibility for wrong conclusions |
#
# > **AI is a power tool, not a replacement for thinking.**
# > A chainsaw makes a carpenter faster, but you still need to know what to build.
#
# ### 7.3 The Danger of "Vibe Coding"
#
# "Vibe coding" = asking AI to generate code without understanding what it does.
#
# ```
# Student: "Write a Python script to analyze my dataset"
# AI:       [generates 50 lines of code]
# Student:  [runs it, gets output]
# Student:  "Done! But... what does this output mean?"
# ```
#
# **This is dangerous in statistics because:**
# - AI might choose the **wrong statistical test** for your data
# - AI might **ignore assumptions** (normality, independence, sample size)
# - AI might produce results that **look correct but are meaningless**
# - You cannot defend your methodology in a paper review or thesis defense
#
# ### 7.4 The Right Way to Use AI
#
# | Level | Usage | Example |
# |-------|-------|---------|
# | **1. AI as Tutor** | Ask it to explain concepts | *"Explain p-value in simple terms"* |
# | **2. AI as Assistant** | Debug your own code | *"My code gives ValueError on line 15"* |
# | **3. AI as Reference** | Find code examples, then adapt | *"Show me a t-test in scipy"* → read → modify |
# | **4. AI as Ghost Writer** | Copy-paste without understanding | **NOT acceptable** |
#
# ### 7.5 The "Explain It Back" Test
#
# > After using AI, ask yourself: **"Can I explain this code, line by line, to my classmate?"**
# > - **Yes** → You learned something.
# > - **No** → You just copied. Go back and understand it.
#
# ### 7.6 Our AI Policy
#
# | Situation | Rule |
# |-----------|------|
# | Understanding concepts | Fully allowed — use AI as a tutor |
# | Debugging your code | Fully allowed — show AI your attempt first |
# | Homework | Allowed with citation — note what AI helped with |
# | Paper replication | Allowed as tool — you must explain every line |
# | Exams (if any) | Not allowed |
#
# ### 7.7 What This Means for Your Career
#
# ```
# ┌───────────────────────────────────────────────────────────────┐
# │                                                               │
# │   2020: "Can you code?"           → Gets you the job         │
# │                                                               │
# │   2026: "Can you code?"           → Everyone can (with AI)   │
# │         "Do you understand the    → Gets you the job          │
# │          statistics behind it?"                               │
# │         "Can you interpret the    → Gets you promoted         │
# │          results and make                                     │
# │          decisions?"                                          │
# │                                                               │
# └───────────────────────────────────────────────────────────────┘
# ```
#
# > **The goal of this course is not to make you a coder.**
# > **The goal is to make you a thinker who can use code as a tool.**
# > AI makes coding easier — which means **statistical thinking** is your real competitive advantage.
#
# ### 7.8 Recommended AI Tools
#
# | Tool | Best For | Free? |
# |------|----------|-------|
# | **ChatGPT** (OpenAI) | Explaining concepts, general Q&A | Free tier |
# | **Claude** (Anthropic) | Detailed code explanations, long analysis | Free tier |
# | **GitHub Copilot** | Code auto-completion in VS Code | Free for students |
# | **Cursor** | AI-powered code editor | Free tier |
# | **Perplexity** | Research with citations | Free tier |

# %% [markdown]
# ---
# ## 8. Jupyter Quick Tour
#
# ### 8.1 Key Shortcuts
#
# | Shortcut | Action |
# |----------|--------|
# | `Shift + Enter` | Run cell, move to next |
# | `Ctrl + Enter` | Run cell, stay in place |
# | `A` / `B` | Insert cell above / below |
# | `M` / `Y` | Switch to Markdown / Code |
# | `DD` | Delete cell |
#
# ### 8.2 Try It!

# %%
print("Hello! You just ran your first code cell!")

# %% [markdown]
# ### 8.3 Markdown Quick Reference
#
# Double-click this cell to see the source, then `Shift + Enter` to render.
#
# **Bold**, *Italic*, `inline code`
#
# Math (LaTeX): The mean is $\bar{x} = \frac{1}{n}\sum_{i=1}^{n} x_i$

# %% [markdown]
# ---
# ## 9. A Taste of What's Coming
#
# Don't worry about understanding the code below — that's what the next 17 weeks are for!
# Just **run each cell** and enjoy the output.

# %%
# Python as a calculator
print("What is 2 to the power of 10?")
print(2 ** 10)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 random exam scores — a Normal Distribution
np.random.seed(42)
scores = np.random.normal(loc=75, scale=10, size=1000)

plt.figure(figsize=(10, 5))
plt.hist(scores, bins=30, color="#3498db", edgecolor="white", alpha=0.8)
plt.axvline(x=np.mean(scores), color="red", linestyle="--", linewidth=2,
            label=f"Mean = {np.mean(scores):.1f}")
plt.title("Distribution of 1000 Exam Scores", fontsize=16)
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Mean: {np.mean(scores):.1f}  |  Std: {np.std(scores):.1f}  |  Min: {np.min(scores):.1f}  |  Max: {np.max(scores):.1f}")

# %% [markdown]
# > This is a **Normal Distribution** — the bell curve, the most important distribution in statistics.
# > We generated it with just 2 lines of Python. We'll study it in depth in **Week 6**.

# %%
# Does studying more lead to higher scores?
np.random.seed(42)
study_hours = np.random.uniform(1, 10, 50)
exam_score = 50 + 4 * study_hours + np.random.normal(0, 5, 50)

plt.figure(figsize=(8, 5))
plt.scatter(study_hours, exam_score, color="#3498db", alpha=0.7, edgecolors="white", s=80)

# Trend line
z = np.polyfit(study_hours, exam_score, 1)
p = np.poly1d(z)
x_line = np.linspace(1, 10, 100)
plt.plot(x_line, p(x_line), color="#e74c3c", linewidth=2, linestyle="--",
         label=f"Trend: score = {z[0]:.1f} × hours + {z[1]:.1f}")

plt.title("Study Hours vs Exam Score", fontsize=16)
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# > **Think about it:**
# > - Is there a relationship between study hours and exam scores?
# > - Is this **correlation** or **causation**?
# > - How confident can we be in this trend line?
# >
# > These are exactly the questions you'll answer in **Week 9: Regression**.

# %% [markdown]
# ---
# ## 10. Summary
#
# | # | What We Covered | Key Takeaway |
# |---|----------------|-------------|
# | 1 | Course structure | 5 parts over 18 weeks: Python → Stats → Scraping → ML/AI → Paper replication |
# | 2 | Why Python, not R | Python covers statistics + ML + AI; best ROI on your learning |
# | 3 | Anaconda | All-in-one toolkit; conda manages packages & environments |
# | 4 | AI-era learning | Use AI as tutor & assistant, not ghost writer; thinking is your edge |
# | 5 | Jupyter Notebook | Interactive environment: code + text + visualization |
# | 6 | First taste | Normal distribution, scatter plot — a preview of the semester |

# %% [markdown]
# ---
# ## 11. Homework (Week 1)
#
# ### Task 1: Install & Verify
# - Install Anaconda on your laptop
# - Open this notebook in Jupyter and **run all cells**
# - Take a screenshot of the verification cell output
#
# > **No laptop?** You can use [Google Colab](https://colab.research.google.com/) — a free, cloud-based Jupyter environment from Google. No installation needed, just a Google account.
#
# ### Task 2: AI Experiment
# Create a new notebook `HW01_YourName.ipynb` (locally or on [Google Colab](https://colab.research.google.com/)):
# 1. Pick **one** AI tool (ChatGPT, Claude, etc.)
# 2. Ask it: *"Write Python code to calculate the mean and standard deviation of a list of numbers, and plot a histogram"*
# 3. Paste the AI's code into a code cell and **run it** — does it work?
# 4. In a Markdown cell, write 3–4 sentences:
#    - What did the AI get right?
#    - Did you understand every line? Which parts confused you?
#    - What would you change?
#
# ### Task 3: Explore (Optional)
# - Browse [Kaggle Datasets](https://www.kaggle.com/datasets) and find one dataset that interests you
# - Write 2–3 sentences about what questions you'd like to answer with it

# %% [markdown]
# ---
# ## Next Week Preview
#
# **Week 2: Python Essentials** — We start coding for real:
# - Variables, data types (`int`, `float`, `str`, `bool`)
# - Lists, dictionaries, tuples
# - Control flow: `if/elif/else`, `for`, `while`
# - Functions: defining, calling, returning
# - List comprehension
#
# **Come prepared:** Make sure Anaconda is installed and working!
#
# ---
# *Applied Statistics with Python (2026) | Week 1 | Course Introduction & Python Setup*
