# %% [markdown]
# # Lecture 02 Exercises: Python Essentials
#
# # Applied Statistics with Python (2026)
#
# ---
#
# Complete the exercises below to practice what you learned in Lecture 02.
# Write your code in the empty cells, then run them to check your output.
#
# **Tips:**
# - Read each problem carefully before coding
# - Test your functions with the provided test cases
# - Solutions are at the bottom — try on your own first!

# %% [markdown]
# ---
# ## Part 1: Variables & Data Types
#
# ### Exercise 1.1: Type Detective
#
# Predict the type and value of each expression below, then run the cell to check.
#
# ```python
# a = 10 / 3
# b = 10 // 3
# c = 10 % 3
# d = 10 ** 0.5
# e = bool(0)
# f = bool("")
# g = bool(" ")
# ```

# %%
# Print each variable's value and type
# Example: print(f"a = {a}, type = {type(a)}")

# %% [markdown]
# ### Exercise 1.2: Temperature Converter
#
# Write a function `celsius_to_fahrenheit(temps)` that:
# - Takes a list of Celsius temperatures
# - Returns a list of Fahrenheit temperatures
# - Formula: F = C × 9/5 + 32

# %%
# Your code here



# Test: should print [32.0, 50.0, 68.0, 86.0, 104.0]
# print(celsius_to_fahrenheit([0, 10, 20, 30, 40]))

# %% [markdown]
# ---
# ## Part 2: Strings
#
# ### Exercise 2.1: String Surgery
#
# Given the string `s = "Applied Statistics 2026"`, use string methods and slicing to produce:
# 1. `"APPLIED STATISTICS 2026"`
# 2. `"applied statistics 2026"`
# 3. `"Applied"` (first word only)
# 4. `"6202 scitsitatS deilppA"` (reversed)
# 5. `"Apple Sttstcs 2026"` (remove all `i` characters)

# %%
s = "Applied Statistics 2026"

# Your code here

# %% [markdown]
# ### Exercise 2.2: CSV Parser
#
# Given the string below, parse it into a list of dictionaries.
#
# ```python
# csv_data = "Alice,22,92\nBob,21,78\nCharlie,23,85"
# ```
#
# Expected output:
# ```python
# [{"name": "Alice", "age": 22, "score": 92},
#  {"name": "Bob", "age": 21, "score": 78},
#  {"name": "Charlie", "age": 23, "score": 85}]
# ```

# %%
csv_data = "Alice,22,92\nBob,21,78\nCharlie,23,85"

# Your code here

# %% [markdown]
# ---
# ## Part 3: Data Structures
#
# ### Exercise 3.1: Word Counter
#
# Write a function `count_words(text)` that:
# - Takes a string
# - Returns a dictionary of word → count
# - Ignores case ("The" and "the" are the same word)

# %%
# Your code here



# Test:
# text = "The cat sat on the mat The cat likes the mat"
# print(count_words(text))
# Should print: {'the': 4, 'cat': 2, 'sat': 1, 'on': 1, 'mat': 2, 'likes': 1}

# %% [markdown]
# ### Exercise 3.2: Set Operations
#
# Two classes have the following students:
# ```python
# math_class = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
# stats_class = {"Bob", "Diana", "Frank", "Grace", "Eve"}
# ```
#
# Find:
# 1. Students in **both** classes
# 2. Students in **either** class (no duplicates)
# 3. Students **only** in math
# 4. Students in **exactly one** class (not both)

# %%
math_class = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
stats_class = {"Bob", "Diana", "Frank", "Grace", "Eve"}

# Your code here

# %% [markdown]
# ### Exercise 3.3: Tuple Unpacking
#
# Given a list of tuples representing (name, age, city):
# ```python
# people = [("Alice", 22, "Beijing"), ("Bob", 25, "Shanghai"), ("Charlie", 21, "Guangzhou")]
# ```
#
# 1. Use tuple unpacking in a `for` loop to print each person's info
# 2. Sort the list by age (hint: use `sorted()` with `key=lambda ...`)
# 3. Find the youngest person's name

# %%
people = [("Alice", 22, "Beijing"), ("Bob", 25, "Shanghai"), ("Charlie", 21, "Guangzhou")]

# Your code here

# %% [markdown]
# ---
# ## Part 4: Control Flow
#
# ### Exercise 4.1: Grade Report
#
# Given a dictionary of student names and scores:
# 1. Print each student's name, score, and letter grade
# 2. Print the class average
# 3. Print the names of students who scored above the average
#
# Grade scale: A (≥90), B (≥80), C (≥70), D (≥60), F (<60)

# %%
class_data = {
    "Alice": 92,
    "Bob": 78,
    "Charlie": 85,
    "Diana": 95,
    "Eve": 67,
    "Frank": 88,
    "Grace": 72,
    "Henry": 90,
}

# Your code here

# %% [markdown]
# ### Exercise 4.2: FizzBuzz
#
# Print numbers 1 to 30, but:
# - For multiples of 3, print "Fizz"
# - For multiples of 5, print "Buzz"
# - For multiples of both 3 and 5, print "FizzBuzz"
# - Otherwise, print the number

# %%
# Your code here

# %% [markdown]
# ### Exercise 4.3: Guess the Number (while loop)
#
# Use a `while` loop to simulate a number guessing game:
# - The secret number is `42`
# - Start with `guess = 0`, and increment by 7 each iteration
# - Print each guess
# - Stop when `guess == 42` and print "Found it!"
# - Also count how many guesses it took

# %%
secret = 42

# Your code here

# %% [markdown]
# ---
# ## Part 5: Functions
#
# ### Exercise 5.1: Statistics Calculator
#
# Write a function `analyze_scores(scores)` that takes a list of numbers and returns a dictionary:
# ```python
# {"count": 10, "mean": 82.6, "median": 84.0, "std": 8.7, "min": 67, "max": 95}
# ```
# Do **NOT** use NumPy — implement the calculations yourself.
#
# Hints:
# - Median: sort the list, pick the middle value (or average of two middle values)
# - Std: `sqrt(sum((x - mean)² for x in data) / n)`

# %%
import math

# Your code here



# Test:
# scores = [78, 92, 85, 67, 95, 88, 72, 90, 83, 76]
# print(analyze_scores(scores))

# %% [markdown]
# ### Exercise 5.2: Data Processing Pipeline
#
# Given the raw data string below:
# ```python
# raw = "Alice:85,Bob:92,Charlie:78,Diana:95,Eve:67,Frank:88"
# ```
#
# Write functions to:
# 1. `parse_data(raw)` → returns `{"Alice": 85, "Bob": 92, ...}`
# 2. `top_students(data, n=3)` → returns top n students by score
# 3. `grade_summary(data)` → returns count of each grade (A, B, C, D, F)

# %%
raw = "Alice:85,Bob:92,Charlie:78,Diana:95,Eve:67,Frank:88"

# Your code here

# %% [markdown]
# ### Exercise 5.3: Lambda & Sorting
#
# Given the following list of students:
# ```python
# students = [("Alice", 85), ("Bob", 92), ("Charlie", 78), ("Diana", 95)]
# ```
#
# Use `sorted()` with a `lambda` function to:
# 1. Sort by score (ascending)
# 2. Sort by score (descending)
# 3. Sort by name length

# %%
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78), ("Diana", 95)]

# Your code here

# %% [markdown]
# ---
# ## Part 6: List Comprehension
#
# ### Exercise 6.1: Comprehension Practice
#
# Use list/dict comprehension to create:
# 1. A list of squares of even numbers from 1 to 20
# 2. A list of words longer than 4 characters from a sentence
# 3. A dictionary mapping numbers 1-10 to their cubes
# 4. A flattened list from `[[1,2],[3,4],[5,6]]`

# %%
# Your code here

# 1. Squares of even numbers from 1 to 20


# 2. Words longer than 4 characters
sentence = "The quick brown fox jumps over the lazy dog"


# 3. Dictionary: number → cube


# 4. Flatten nested list
nested = [[1, 2], [3, 4], [5, 6]]

# %% [markdown]
# ---
# ## Part 6B: File I/O
#
# ### Exercise 6B.1: Write and Read a File
#
# 1. Write a list of names to a file `names.txt` (one name per line)
# 2. Read the file back and print each name with a line number
# 3. Use the `with` statement for both operations
#
# ```python
# names = ["Alice", "Bob", "Charlie", "Diana", "Eve"]
# ```

# %%
names = ["Alice", "Bob", "Charlie", "Diana", "Eve"]

# Your code here

# %% [markdown]
# ---
# ## Part 6C: Error Handling Basics
#
# ### Exercise 6C.1: Safe Division
#
# Write a function `safe_divide(a, b)` that:
# - Returns `a / b` if possible
# - Handles `ZeroDivisionError` and returns `None`
# - Handles `TypeError` (e.g., `"hello" / 2`) and returns `None`
# - Prints a friendly error message in each case

# %%
# Your code here



# Test:
# print(safe_divide(10, 3))      # 3.333...
# print(safe_divide(10, 0))      # None (ZeroDivisionError)
# print(safe_divide("hello", 2)) # None (TypeError)

# %% [markdown]
# ### Exercise 6C.2: Safe List Access
#
# Write a function `safe_get(lst, index, default="N/A")` that:
# - Returns `lst[index]` if the index is valid
# - Returns `default` if the index is out of range
# - Use `try/except IndexError`

# %%
# Your code here



# Test:
# fruits = ["apple", "banana", "cherry"]
# print(safe_get(fruits, 1))       # banana
# print(safe_get(fruits, 10))      # N/A
# print(safe_get(fruits, 10, "unknown"))  # unknown

# %% [markdown]
# ---
# ## Part 7: Classes & OOP
#
# ### Exercise 7.1: Student Class
#
# Create a `StudentRecord` class that:
# - Has attributes: `name`, `scores` (list of floats)
# - Has methods:
#   - `add_score(score)` — validates score (0-100) before adding
#   - `average()` — returns the average score
#   - `best_score()` — returns the highest score
#   - `grade()` — returns letter grade based on average
#   - `__str__()` — returns a readable string representation

# %%
# Your code here



# Test:
# s = StudentRecord("Alice")
# s.add_score(92)
# s.add_score(85)
# s.add_score(78)
# s.add_score(150)  # should be rejected
# print(s)
# print(f"Average: {s.average():.1f}")
# print(f"Best: {s.best_score()}")
# print(f"Grade: {s.grade()}")

# %% [markdown]
# ### Exercise 7.2: Custom Exception
#
# Create a `GradeBook` class with custom exceptions:
# - Define `DuplicateStudentError` — raised when adding a student that already exists
# - Define `StudentNotFoundError` — raised when looking up a student that doesn't exist
# - The `GradeBook` should support: `add_student(name, score)`, `get_score(name)`, `remove_student(name)`

# %%
# Your code here



# Test:
# gb = GradeBook()
# gb.add_student("Alice", 92)
# gb.add_student("Bob", 78)
# print(gb.get_score("Alice"))       # 92
# gb.add_student("Alice", 85)        # should raise DuplicateStudentError
# gb.get_score("Charlie")            # should raise StudentNotFoundError

# %% [markdown]
# ---
# ## Part 8: Comprehensive Challenge
#
# ### Exercise 8.1: Mini Grade Management System
#
# Build a complete grade management system that combines everything you've learned:
#
# 1. Read student data from the CSV string below
# 2. Create `Student` objects for each student
# 3. Calculate statistics (mean, median, highest, lowest)
# 4. Generate a formatted report
# 5. Use error handling for invalid data
#
# ```python
# csv_input = """Name,Midterm,Final
# Alice,88,92
# Bob,75,80
# Charlie,92,88
# Diana,N/A,95
# Eve,68,72
# Frank,85,90
# Grace,78,65
# Henry,90,93"""
# ```
#
# Expected output should include:
# - Each student's weighted average (Midterm 40%, Final 60%)
# - Handle `N/A` values gracefully
# - Class statistics
# - Students sorted by weighted average

# %%
csv_input = """Name,Midterm,Final
Alice,88,92
Bob,75,80
Charlie,92,88
Diana,N/A,95
Eve,68,72
Frank,85,90
Grace,78,65
Henry,90,93"""

# Your code here

# %% [markdown]
# ---
# ## Solutions
#
# ⚠️ **Try the exercises on your own first before looking at the solutions!**

# %%
# Exercise 1.1: Type Detective
a = 10 / 3
b = 10 // 3
c = 10 % 3
d = 10 ** 0.5
e = bool(0)
f = bool("")
g = bool(" ")

for name, val in [("a", a), ("b", b), ("c", c), ("d", d), ("e", e), ("f", f), ("g", g)]:
    print(f"{name} = {val}, type = {type(val).__name__}")

# %%
# Exercise 1.2: Temperature Converter
def celsius_to_fahrenheit(temps):
    return [c * 9/5 + 32 for c in temps]

print(celsius_to_fahrenheit([0, 10, 20, 30, 40]))

# %%
# Exercise 2.1: String Surgery
s = "Applied Statistics 2026"
print(s.upper())
print(s.lower())
print(s.split()[0])
print(s[::-1])
print(s.replace("i", ""))

# %%
# Exercise 2.2: CSV Parser
csv_data = "Alice,22,92\nBob,21,78\nCharlie,23,85"

result = []
for line in csv_data.split("\n"):
    name, age, score = line.split(",")
    result.append({"name": name, "age": int(age), "score": int(score)})
print(result)

# %%
# Exercise 3.1: Word Counter
def count_words(text):
    words = text.lower().split()
    freq = {}
    for word in words:
        freq[word] = freq.get(word, 0) + 1
    return freq

text = "The cat sat on the mat The cat likes the mat"
print(count_words(text))

# %%
# Exercise 3.2: Set Operations
math_class = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
stats_class = {"Bob", "Diana", "Frank", "Grace", "Eve"}

print(f"Both:      {math_class & stats_class}")
print(f"Either:    {math_class | stats_class}")
print(f"Only math: {math_class - stats_class}")
print(f"Exactly 1: {math_class ^ stats_class}")

# %%
# Exercise 3.3: Tuple Unpacking
people = [("Alice", 22, "Beijing"), ("Bob", 25, "Shanghai"), ("Charlie", 21, "Guangzhou")]

# 1. Tuple unpacking in for loop
for name, age, city in people:
    print(f"{name}, age {age}, from {city}")

# 2. Sort by age
print(sorted(people, key=lambda p: p[1]))

# 3. Youngest person
youngest = min(people, key=lambda p: p[1])
print(f"Youngest: {youngest[0]}")

# %%
# Exercise 4.1: Grade Report
class_data = {
    "Alice": 92, "Bob": 78, "Charlie": 85, "Diana": 95,
    "Eve": 67, "Frank": 88, "Grace": 72, "Henry": 90,
}

def get_grade(score):
    if score >= 90: return "A"
    elif score >= 80: return "B"
    elif score >= 70: return "C"
    elif score >= 60: return "D"
    else: return "F"

print(f"{'Name':<12} {'Score':>6} {'Grade':>6}")
print("=" * 26)
for name, score in class_data.items():
    print(f"{name:<12} {score:>6} {get_grade(score):>6}")

avg = sum(class_data.values()) / len(class_data)
print(f"\nAverage: {avg:.1f}")
above = [n for n, s in class_data.items() if s > avg]
print(f"Above average: {', '.join(above)}")

# %%
# Exercise 4.2: FizzBuzz
for i in range(1, 31):
    if i % 15 == 0:
        print("FizzBuzz", end=" ")
    elif i % 3 == 0:
        print("Fizz", end=" ")
    elif i % 5 == 0:
        print("Buzz", end=" ")
    else:
        print(i, end=" ")

# %%
# Exercise 4.3: Guess the Number (while loop)
secret = 42
guess = 0
count = 0

while guess != secret:
    guess += 7
    count += 1
    print(f"Guess #{count}: {guess}")

print(f"Found it! Took {count} guesses.")

# %%
# Exercise 5.1: Statistics Calculator
import math

def analyze_scores(scores):
    n = len(scores)
    mean = sum(scores) / n
    sorted_s = sorted(scores)
    if n % 2 == 0:
        median = (sorted_s[n//2 - 1] + sorted_s[n//2]) / 2
    else:
        median = sorted_s[n//2]
    std = math.sqrt(sum((x - mean) ** 2 for x in scores) / n)
    return {"count": n, "mean": round(mean, 1), "median": median,
            "std": round(std, 1), "min": min(scores), "max": max(scores)}

scores = [78, 92, 85, 67, 95, 88, 72, 90, 83, 76]
print(analyze_scores(scores))

# %%
# Exercise 6.1: Comprehension Practice
print([x**2 for x in range(1, 21) if x % 2 == 0])

sentence = "The quick brown fox jumps over the lazy dog"
print([w for w in sentence.split() if len(w) > 4])

print({n: n**3 for n in range(1, 11)})

nested = [[1, 2], [3, 4], [5, 6]]
print([x for row in nested for x in row])

# %%
# Exercise 5.3: Lambda & Sorting
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78), ("Diana", 95)]

# 1. Sort by score ascending
print(sorted(students, key=lambda s: s[1]))

# 2. Sort by score descending
print(sorted(students, key=lambda s: s[1], reverse=True))

# 3. Sort by name length
print(sorted(students, key=lambda s: len(s[0])))

# %%
# Exercise 6B.1: Write and Read a File
names = ["Alice", "Bob", "Charlie", "Diana", "Eve"]

# Write
with open("names.txt", "w") as f:
    for name in names:
        f.write(name + "\n")

# Read
with open("names.txt", "r") as f:
    for i, line in enumerate(f, 1):
        print(f"{i}. {line.strip()}")

# %%
# Exercise 6C.1: Safe Division
def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        print("Error: cannot divide by zero!")
        return None
    except TypeError:
        print("Error: invalid types for division!")
        return None

print(safe_divide(10, 3))
print(safe_divide(10, 0))
print(safe_divide("hello", 2))

# %%
# Exercise 6C.2: Safe List Access
def safe_get(lst, index, default="N/A"):
    try:
        return lst[index]
    except IndexError:
        return default

fruits = ["apple", "banana", "cherry"]
print(safe_get(fruits, 1))
print(safe_get(fruits, 10))
print(safe_get(fruits, 10, "unknown"))

# %%
# Exercise 7.1: Student Class
class StudentRecord:
    def __init__(self, name):
        self.name = name
        self.scores = []
    
    def add_score(self, score):
        if not isinstance(score, (int, float)) or score < 0 or score > 100:
            print(f"Invalid score: {score}")
            return
        self.scores.append(score)
    
    def average(self):
        return sum(self.scores) / len(self.scores) if self.scores else 0
    
    def best_score(self):
        return max(self.scores) if self.scores else 0
    
    def grade(self):
        avg = self.average()
        if avg >= 90: return "A"
        elif avg >= 80: return "B"
        elif avg >= 70: return "C"
        elif avg >= 60: return "D"
        else: return "F"
    
    def __str__(self):
        return f"StudentRecord('{self.name}', scores={self.scores})"

s = StudentRecord("Alice")
s.add_score(92)
s.add_score(85)
s.add_score(78)
s.add_score(150)
print(s)
print(f"Average: {s.average():.1f}, Best: {s.best_score()}, Grade: {s.grade()}")

# %%
# Exercise 7.2: Custom Exception
class DuplicateStudentError(Exception):
    def __init__(self, name):
        super().__init__(f"Student '{name}' already exists")

class StudentNotFoundError(Exception):
    def __init__(self, name):
        super().__init__(f"Student '{name}' not found")

class GradeBook:
    def __init__(self):
        self.records = {}
    
    def add_student(self, name, score):
        if name in self.records:
            raise DuplicateStudentError(name)
        self.records[name] = score
        print(f"Added {name}: {score}")
    
    def get_score(self, name):
        if name not in self.records:
            raise StudentNotFoundError(name)
        return self.records[name]
    
    def remove_student(self, name):
        if name not in self.records:
            raise StudentNotFoundError(name)
        del self.records[name]
        print(f"Removed {name}")

gb = GradeBook()
gb.add_student("Alice", 92)
gb.add_student("Bob", 78)
print(f"Alice's score: {gb.get_score('Alice')}")

try:
    gb.add_student("Alice", 85)
except DuplicateStudentError as e:
    print(f"Error: {e}")

try:
    gb.get_score("Charlie")
except StudentNotFoundError as e:
    print(f"Error: {e}")

# %% [markdown]
# ---
# *Applied Statistics with Python (2026) | Lecture 02 Exercises | Python Essentials*
